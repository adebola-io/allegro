# %%
# Import pandas library
import pandas as pd

# Define the data as a list of lists
data = [
    [1, 1.6252, 0.5288, 1.3960, 0.5759],
    [2, 1.1785, 0.6299, 1.3961, 0.5691],
    [3, 0.7908, 0.7497, 1.5492, 0.5686],
    [4, 0.4684, 0.8582, 1.7667, 0.5562]
]

# Define the column names as a list
columns = ["Epoch", "Train loss", "Train accuracy",
           "Validation loss", "Validation accuracy"]

# Create the DataFrame from the data and columns
df = pd.DataFrame(data=data, columns=columns)

# Display the DataFrame
print(df)


# Plot the line plot for each column
ax = df.plot.line(x="Epoch")
# Out:
#    Epoch  Train loss  Train accuracy  Validation loss  Validation accuracy
# 0      1      1.6252          0.5288           1.3960               0.5759
# 1      2      1.1785          0.6299           1.3961               0.5691
# 2      3      0.7908          0.7497           1.5492               0.5686
# 3      4      0.4684          0.8582           1.7667               0.5562

# %%
import pandas as pd

data = {
    'accuracy': [0.55],
    'macro avg precision': [0.48],
    'macro avg recall': [0.45],
    'macro avg f1-score': [0.45],
    'macro avg support': [5427],
    'weighted avg precision': [0.55],
    'weighted avg recall': [0.55],
    'weighted avg f1-score': [0.54],
    'weighted avg support': [5427]
}

results_df = pd.DataFrame(data)
print(results_df.to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>accuracy</th>
#       <th>macro avg precision</th>
#       <th>macro avg recall</th>
#       <th>macro avg f1-score</th>
#       <th>macro avg support</th>
#       <th>weighted avg precision</th>
#       <th>weighted avg recall</th>
#       <th>weighted avg f1-score</th>
#       <th>weighted avg support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.55</td>
#       <td>0.48</td>
#       <td>0.45</td>
#       <td>0.45</td>
#       <td>5427</td>
#       <td>0.55</td>
#       <td>0.55</td>
#       <td>0.54</td>
#       <td>5427</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Out:
# <>:17: SyntaxWarning: 'ellipsis' object is not subscriptable; perhaps you missed a comma?
# <>:17: SyntaxWarning: 'ellipsis' object is not subscriptable; perhaps you missed a comma?
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17940\2394395701.py:17: SyntaxWarning: 'ellipsis' object is not subscriptable; perhaps you missed a comma?
#   ...  # Continue adding rows for each class
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 17
#       7 class_labels = [
#       8     '0', '1', '10', '11', '12', '13', '14', '15', '16', '17',
#       9     '18', '19', '2', '20', '21', '22', '23', '24', '25', '26',
#      10     '27', '3', '4', '5', '6', '7', '8', '9'
#      11 ]
#      13 # Define the confusion matrix data
#      14 confusion_data = [
#      15     [354, 12, 10, ..., 2, 12, 4],
#      16     [16, 212, 7, ..., 0, 3, 1],
# ---> 17     ...  # Continue adding rows for each class
#      18     [3, 3, 0, ..., 92, 11, 8]
#      19 ]
#      21 # Create a pandas DataFrame from the confusion matrix data
#      22 confusion_df = pd.DataFrame(
#      23     confusion_data, index=class_labels, columns=class_labels)
#
# TypeError: 'ellipsis' object is not subscriptable
