# %%
# %pip install matplotlib
# Out:
# ...
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/4d/9c/65830d4a56c47f5283eaa244dc1228c5da9c844a9f999ebcc2e69bf6cc65/matplotlib-3.7.2-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/16/09/989b982322439faa4bafffcd669e6f942b38fee897c2664c987bcd091dec/contourpy-1.1.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/52/65/aaa3d2b7a292d93cc2cf1c534d03ba3f744e480f15b3b2ab6ad68189f7ee/fonttools-4.42.0-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/153.7 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/153.7 kB ? eta -:--:--
#      ------- ----------------------------- 30.7/153.7 kB 660.6 kB/s eta 0:00:01
#      ------- ----------------------------- 30.7/153.7 kB 660.6 kB/s eta 0:00:01
# ...

# %%
import pandas as pd

data: dict[str, list[str|int]] = {
    "Emotions": ["Admiration", "Amusement", "Anger", "Annoyance", "Approval", "Caring", "Confusion", "Curiosity", "Desire", "Disappointment", "Disapproval", "Disgust", "Embarrassment", "Excitement", "Fear", "Gratitude", "Grief", "Joy", "Love", "Nervousness", "Neutral", "Optimism", "Pride", "Realization", "Relief", "Remorse", "Sadness", "Surprise"],
    "Training": [4130, 2328, 1567, 2470, 2939, 1087, 1368, 2191, 641, 1269, 2022, 793, 303, 853, 596, 2662, 77, 1452, 2086, 164, 14219, 1581, 111, 1110, 153, 545, 1326, 1060], 
    "Validation": [488, 303, 195, 303, 397, 153, 152, 248, 77, 163, 292, 97, 35, 96, 90, 358, 13, 172, 252, 21, 1766, 209, 15, 127, 18, 68, 143, 129], 
    "Testing": [504, 264, 198, 320, 351, 135, 153, 284, 83, 151, 267, 123, 37, 103, 78, 352, 6, 161, 238, 23, 1787, 186, 16, 145, 11, 56, 156, 141]
    }

df = pd.DataFrame(data=data)

# %%
ax = df.plot.bar(x="Emotions", rot=90)
